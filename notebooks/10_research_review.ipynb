# %% [markdown]
# # 最新HGB比較の保存結果を読む
# FX (2).ipynb セル58から抽出。独立再実行・データ品質監査は未完了。CHAMPIONは候補名です。
# このNotebookはCSV表示だけを行い、モデルの学習やデータ取得はしません。

# %%
from pathlib import Path
import pandas as pd
root = Path.cwd()
if root.name == 'notebooks':
    root = root.parent
results = root / 'results' / 'published'
assert results.exists(), 'Run from the repository root or notebooks directory.'

# %%
pd.read_csv(results / 'hgb_development_saved.csv')

# %%
pd.read_csv(results / 'hgb_annual_saved.csv')

# %%
pd.read_csv(results / 'hgb_cost_saved.csv')
