# %% [markdown]
# # 再構築データと仮想売買の保存結果
# FX (3).ipynbの保存出力を読むためのNotebookです。再学習・API接続・仮想売買は開始しません。
# 300取引は過去の再現。最新API記録は待機・処理0件です。

# %%
from pathlib import Path
import json
import pandas as pd
root = Path.cwd()
if root.name == 'notebooks':
    root = root.parent
results = root / 'results' / 'published'

# %%
pd.read_csv(results / 'clean_development_saved.csv')

# %%
pd.read_csv(results / 'clean_confirmation_saved.csv')

# %%
pd.read_csv(results / 'clean_annual_saved.csv')

# %%
json.loads((results / 'frozen_contract_saved.json').read_text(encoding='utf-8'))
